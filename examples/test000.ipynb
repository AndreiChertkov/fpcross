# %%
import numpy as np

from fpcross import ij, Grid, Func, Solver, Model, Check

ij()
# Out:
# Start |  2:18PM MSK on Nov 29, 2019 | python 3.7.1    |
# -------------------------------------------------------
# <style>
#         div {
#           margin: 0;
#           padding: 0;
#         }
#
#         .head0 {
#           padding: 10px;
#           display: flex;
#           background-color: #dedee2;
#         }
#         .head0__name {
#           padding-right: 5px;
#           flex: 1 1 50%;
#           align-self: center;
#           font-size: 36px;
#           font-weight: bold;
#           color: #6b7e51;
#         }
#         .head0__note {
#           padding-left: 10px;
#           flex: 1 1 50%;
#           align-self: flex-end;
#           font-size: 16px;
#           font-style: italic;
#           color: #485536;
#           border-left: 5px solid #8b1d1d;
#         }
#
#         .head1 {
#           margin-top: 30px;
#           padding: 10px;
#           border-top: 5px solid #8b1d1d;
#         }
#         .head1__name {
#           font-size: 32px;
#           font-weight: bold;
#           color: #485536;
#         }
#         .head1__note {
#           padding-left: 20px;
#           font-size: 20px;
#           font-style: italic;
#           color: #485536;
#         }
#
#         .head2 {
#           margin-top: 7px;
#           padding: 5px 30px 5px;
#           border-left: 2px solid #42d56e;
#         }
#         .head2__name {
#           display: inline-block;
#           max-width: 70%;
#           padding: 2px 10px;
#           font-size: 22px;
#           font-weight: bold;
#           color: #145929;
#           border-bottom: 2px solid #42d56e;
#         }
#         .head2__note {
#           padding: 5px 10px 0px;
#           font-size: 14px;
#           font-style: italic;
#           color: #485536;
#         }
#
#         .head3 {
#           margin-top: 5px;
#           padding: 3px 40px 3px;
#           border-left: 2px dotted #485536;
#         }
#         .head3__name {
#           display: inline-block;
#           max-width: 70%;
#           padding: 2px 10px;
#           font-size: 20px;
#           font-weight: bold;
#           color: #145929;
#           border-bottom: 2px dotted #485536;
#         }
#         .head3__note {
#           padding: 2px 10px 0px;
#           font-size: 12px;
#           font-style: italic;
#           color: #485536;
#         }
#
#         .warn {
#           background-color: #fcf2f2;
#           border-color: #dfb5b4;
#           border-left: 5px solid #dfb5b4;
#           padding: 0.5em;
#         }
#
#         .note {
#           color: #42d56e;
#         }
#         .note::before {
#           content: 'Note. ';
#           font-weight: bold;
#           color: #485536;
#         }
#
#         .end {
#           padding: 5px;
#           border-top: 5px solid #8b1d1d;
#           border-bottom: 5px solid #8b1d1d;
#         }
#     </style>

# %%
MD = Model.select('fpe_oup')
MD.init(d=3, s=1., D=0.5, A=np.array([
    [1.0, 0.2, 0.5],
    [0.0, 0.7, 0.3],
    [0.0, 0.0, 1.5],
]))

SL = Solver(
    TG=Grid(d=1, n=  100, l=[+0., +8.], k='u'),
    SG=Grid(d=3, n=  20, l=[-6., +6.], k='c'),
    MD=MD, eps=1.E-4, with_tt=True
).init({
    'n_hst': 0,
    'with_rhs': False,
    'with_r_hst': False,
}).prep()

# %prun SL.calc()

print(len(SL.xxx))
print(np.max(SL.xxx))
print(np.mean(SL.xxx))
print(np.min(SL.xxx))
print(np.sum(SL.xxx))
print(SL.res_conv)
# Out:
# Solve: 100%|██████████████████████████████████| 99/99 [07:27<00:00,  4.29s/step]
#  710018
# 0.2521300039999801
# 0.00020875934381100455
# 0.00015903400000638612
# 148.22289177400182
# {'evals': 5912, 't_func': 0.0, 'iters': 1, 'err_rel': 9e-07, 'err_abs': 2.6e-07, 'erank': 18.5}
#          203316604 function calls (203315000 primitive calls) in 447.775 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    710018   59.540    0.000   69.456    0.000 polycheb.py:3(polycheb)
#   1420036   38.433    0.000  149.365    0.000 ord_solver.py:87(comp)
#   7609620   32.067    0.000   32.067    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    710516   22.741    0.000   25.986    0.000 vector.py:107(to_list)
#    710030   20.909    0.000   29.675    0.000 grid.py:193(comp)
#    710217   19.816    0.000   70.636    0.000 grid.py:65(__init__)
#   2840072   16.906    0.000   96.259    0.000 solver.py:457(func)
#   5680144   15.845    0.000   15.845    0.000 model_fpe_oup.py:140(f0)
#    710018   14.320    0.000  146.417    0.000 func.py:385(comp)
#   2840868   13.779    0.000   35.661    0.000 _methods.py:58(_mean)
#   3566620   13.050    0.000   13.050    0.000 {built-in method numpy.core.multiarray.concatenate}
#    710018   11.855    0.000  391.776    0.001 solver.py:489(step)
#   7100780   11.301    0.000   17.893    0.000 shape_base.py:63(atleast_2d)
#   2141940   10.137    0.000   10.137    0.000 func.py:278(<listcomp>)
#   4268357    9.256    0.000    9.256    0.000 {built-in method numpy.core.multiarray.copyto}
#   4764016    9.101    0.000   30.080    0.000 fromnumeric.py:64(_wrapreduction)
#  11411192    8.960    0.000    8.960    0.000 {built-in method numpy.core.multiarray.array}
#   2840072    8.815    0.000   19.584    0.000 model_fpe_oup.py:145(f1)
#    710018    7.721    0.000   19.165    0.000 grid.py:510(is_out)
#   4260444    7.307    0.000    7.307    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#   7120412    6.833    0.000    6.833    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       894    6.478    0.007  444.551    0.497 func.py:274(func_s)
#    890088    5.335    0.000    5.335    0.000 {built-in method numpy.core.multiarray.c_einsum}
#   2840868    5.231    0.000   40.892    0.000 fromnumeric.py:2817(mean)
#   5680144    5.174    0.000  109.079    0.000 ord_solver.py:130(func)
#   2840868    5.124    0.000    5.465    0.000 _methods.py:48(_count_reduce_items)
#   4269259    4.869    0.000    4.869    0.000 {built-in method numpy.core.multiarray.empty}
#    710030    4.765    0.000  426.590    0.001 func.py:262(func)
#   3550390    4.682    0.000   38.640    0.000 shape_base.py:182(vstack)
#  21305375    4.198    0.000    4.199    0.000 {built-in method builtins.isinstance}
#   2840634    4.194    0.000   21.844    0.000 fromnumeric.py:1821(sum)
#   4268357    3.769    0.000   17.893    0.000 numeric.py:156(ones)
#   3550390    3.543    0.000   21.436    0.000 shape_base.py:234(<listcomp>)
#   9955540    3.414    0.000    6.898    0.000 numeric.py:504(asanyarray)
#   4260444    3.006    0.000   13.537    0.000 fromnumeric.py:404(repeat)
#   1420036    2.832    0.000    3.541    0.000 ord_solver.py:17(__init__)
#   1923382    2.734    0.000   16.027    0.000 fromnumeric.py:2227(amax)
#   4267924    2.409    0.000   10.563    0.000 fromnumeric.py:49(_wrapfunc)
#   2141785    2.315    0.000    2.315    0.000 {method 'copy' of 'numpy.ndarray' objects}
#  14214195    1.684    0.000    1.684    0.000 {built-in method builtins.len}
#   2840072    1.329    0.000    1.329    0.000 ord_solver.py:50(init)
#    710018    1.322    0.000    1.755    0.000 grid.py:623(_prep_poi)
#   9948663    1.283    0.000    1.283    0.000 {method 'append' of 'list' objects}
#   4263318    1.089    0.000    1.089    0.000 {built-in method time.perf_counter}
#    714691    1.040    0.000    1.040    0.000 {method 'astype' of 'numpy.ndarray' objects}
#   4764016    0.961    0.000    0.961    0.000 {method 'items' of 'dict' objects}
#   4977357    0.840    0.000    0.840    0.000 {built-in method builtins.issubclass}
#   4291965    0.834    0.000    0.834    0.000 {built-in method builtins.getattr}
#   2865788    0.824    0.000    0.824    0.000 {built-in method builtins.hasattr}
#    890088    0.774    0.000    6.321    0.000 einsumfunc.py:983(einsum)
#   2141940    0.606    0.000    0.606    0.000 {method 'join' of 'str' objects}
#       369    0.213    0.001    0.240    0.001 vector.py:381(round)
#    890088    0.212    0.000    0.212    0.000 {method 'pop' of 'dict' objects}
#       651    0.194    0.000    0.208    0.000 vector.py:415(norm)
#       906    0.144    0.000    0.162    0.000 linalg.py:1418(svd)
#       200    0.131    0.001    0.131    0.001 {method 'close' of '_io.TextIOWrapper' objects}
#       906    0.096    0.000    0.103    0.000 {tt.cross.rectcross.rect_maxvol.cython_boost.maxvol.c_rect_maxvol}
#       895    0.087    0.000    0.089    0.000 func.py:142(init)
#      6236    0.076    0.000    0.089    0.000 numeric.py:1048(outer)
#       800    0.064    0.000    0.064    0.000 {built-in method numpy.linalg.lapack_lite.dgeqrf}
#       250    0.064    0.000    0.079    0.000 vector.py:354(__add__)
#       100    0.061    0.001    0.062    0.001 {method 'readlines' of '_io._IOBase' objects}
#       200    0.060    0.000    0.062    0.000 {built-in method io.open}
#      6236    0.056    0.000    0.735    0.000 shape_base.py:970(kron)
#      3164    0.052    0.000    0.052    0.000 {built-in method numpy.core.multiarray.dot}
#       905    0.048    0.000    0.048    0.000 {method 'acquire' of '_thread.lock' objects}
#      1608    0.045    0.000    0.138    0.000 numeric.py:1132(tensordot)
#       300    0.043    0.000    0.043    0.000 {mkl_fft._pydfti.fft}
#       400    0.043    0.000    0.050    0.000 {tt.cross.rectcross.rect_maxvol.cython_boost.maxvol.c_maxvol}
#       453    0.027    0.000   88.685    0.196 rect_cross.py:339(update_core_right)
#       453    0.025    0.000  356.995    0.788 rect_cross.py:295(update_core_left)
#     11366    0.023    0.000    0.057    0.000 {built-in method builtins.sorted}
#       400    0.023    0.000    0.156    0.000 linalg.py:738(qr)
#      7210    0.020    0.000    0.020    0.000 {built-in method numpy.core.multiarray.zeros}
#       100    0.020    0.000    0.020    0.000 {built-in method posix.remove}
#       450    0.020    0.000    0.037    0.000 vector.py:423(__rmul__)
#      1347    0.018    0.000    0.018    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#       696    0.018    0.000    0.018    0.000 {method 'copy' of 'dict' objects}
#       300    0.018    0.000    0.077    0.000 func.py:624(interpolate_cheb)
#      5683    0.017    0.000    0.053    0.000 shape_base.py:946(get_array_prepare)
#      3312    0.017    0.000    0.017    0.000 {built-in method numpy.core.multiarray.arange}
#       200    0.015    0.000    0.254    0.001 rect_cross.py:198(left_qr_maxvol)
#       200    0.015    0.000    0.169    0.001 rect_cross.py:229(right_qr_maxvol)
#    1593/1    0.015    0.000  447.775  447.775 utils.py:28(timer__)
#       151    0.015    0.000  445.795    2.952 rect_cross.py:390(iterate)
#       403    0.013    0.000    0.013    0.000 socket.py:334(send)
#       450    0.013    0.000    0.025    0.000 vector.py:544(get_ps)
#       250    0.013    0.000    0.021    0.000 vector.py:126(erank)
#       300    0.013    0.000    0.027    0.000 func.py:702(integrate_cheb_coeffs)
#       100    0.013    0.000    0.058    0.001 func.py:452(comp_int)
#       800    0.013    0.000    0.013    0.000 {built-in method numpy.linalg.lapack_lite.dorgqr}
#     17049    0.012    0.000    0.019    0.000 shape_base.py:951(<genexpr>)
#      1812    0.012    0.000    0.012    0.000 {method 'dot' of 'numpy.ndarray' objects}
#       449    0.011    0.000    0.084    0.000 vector.py:81(from_list)
#        99    0.011    0.000  447.161    4.517 solver.py:443(calc_conv)
#       906    0.011    0.000    0.606    0.001 rect_cross.py:176(index_merge)
#       100    0.010    0.000  446.885    4.469 func.py:238(prep)
#      2167    0.010    0.000    0.035    0.000 vector.py:51(__init__)
#      6130    0.009    0.000    0.040    0.000 rect_cross.py:12(reshape)
#      1520    0.009    0.000    0.017    0.000 type_check.py:185(iscomplex)
#      6236    0.009    0.000    0.744    0.000 rect_cross.py:15(mkron)
#     17049    0.009    0.000    0.014    0.000 shape_base.py:963(<genexpr>)
#      4828    0.008    0.000    0.013    0.000 shape_base.py:11(atleast_1d)
#       906    0.008    0.000    0.013    0.000 twodim_base.py:197(diag)
#       198    0.008    0.000    0.359    0.002 solver.py:416(calc_diff)
#      6130    0.008    0.000    0.031    0.000 fromnumeric.py:185(reshape)
#       400    0.008    0.000    0.008    0.000 {method 'outer' of 'numpy.ufunc' objects}
#      1200    0.007    0.000    0.007    0.000 {built-in method numpy.core.multiarray._fastCopyAndTranspose}
#       199    0.007    0.000    0.082    0.000 func.py:94(copy)
#      5683    0.007    0.000    0.028    0.000 shape_base.py:958(get_array_wrap)
#       100    0.007    0.000  446.523    4.465 rect_cross.py:417(cross)
#        99    0.007    0.000    0.088    0.001 solver.py:704(exam)
#     16994    0.006    0.000    0.012    0.000 numeric.py:433(asarray)
#     12472    0.006    0.000    0.006    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#       400    0.005    0.000    0.032    0.000 twodim_base.py:414(triu)
#       100    0.005    0.000    0.167    0.002 func.py:343(calc)
#      1306    0.005    0.000    0.009    0.000 linalg.py:141(_commonType)
#       100    0.005    0.000    0.025    0.000 rect_cross.py:145(init_alg)
#      1961    0.004    0.000    0.039    0.000 shape_base.py:236(hstack)
#       450    0.004    0.000    0.004    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#      1961    0.004    0.000    0.017    0.000 shape_base.py:283(<listcomp>)
#       100    0.004    0.000    0.427    0.004 rect_cross.py:283(setup_indices)
#       648    0.004    0.000    0.026    0.000 vector.py:559(copy)
#       453    0.004    0.000    0.041    0.000 rect_cross.py:262(apply_Ru)
#       400    0.003    0.000    0.004    0.000 rect_cross.py:27(__init__)
#       400    0.003    0.000    0.003    0.000 {built-in method numpy.core.multiarray.unravel_index}
#      1200    0.003    0.000    0.011    0.000 linalg.py:182(_fastCopyAndTranspose)
#       453    0.003    0.000    0.033    0.000 rect_cross.py:272(apply_Rv)
#      3216    0.003    0.000    0.003    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       800    0.003    0.000    0.005    0.000 twodim_base.py:25(_min_int)
#       100    0.003    0.000    0.006    0.000 grid.py:568(is_sym)
#      1608    0.003    0.000    0.003    0.000 {built-in method builtins.iter}
#      5370    0.003    0.000    0.003    0.000 func.py:225(set_opt)
#       400    0.003    0.000    0.003    0.000 {built-in method numpy.core.multiarray.where}
#      1306    0.003    0.000    0.005    0.000 linalg.py:108(_makearray)
#       400    0.002    0.000    0.022    0.000 twodim_base.py:327(tri)
#      1306    0.002    0.000    0.003    0.000 linalg.py:226(_assertNoEmpty2d)
#      2719    0.002    0.000    0.018    0.000 function_base.py:689(copy)
#      8295    0.002    0.000    0.002    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#      1520    0.002    0.000    0.016    0.000 {method 'any' of 'numpy.ndarray' objects}
#       403    0.002    0.000    0.017    0.000 iostream.py:195(schedule)
#      2212    0.002    0.000    0.003    0.000 linalg.py:126(_realType)
#        99    0.002    0.000    0.080    0.001 _tqdm.py:1040(update)
#      3012    0.002    0.000    0.002    0.000 linalg.py:113(isComplexType)
#        99    0.002    0.000    0.193    0.002 solver.py:534(calc_post)
#       100    0.002    0.000    0.004    0.000 _tqdm.py:236(format_meter)
#      1608    0.002    0.000    0.002    0.000 numeric.py:1301(<listcomp>)
#       100    0.002    0.000    0.007    0.000 rect_cross.py:38(__init__)
#      1608    0.001    0.000    0.001    0.000 numeric.py:1296(<listcomp>)
#      3605    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#       250    0.001    0.000    0.098    0.000 vector.py:455(__sub__)
#       597    0.001    0.000    0.001    0.000 {method 'format' of 'str' objects}
#      1520    0.001    0.000    0.014    0.000 _methods.py:42(_any)
#       906    0.001    0.000    0.001    0.000 linalg.py:103(get_linalg_error_extobj)
#       900    0.001    0.000    0.001    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#       900    0.001    0.000    0.004    0.000 fromnumeric.py:506(swapaxes)
#      5683    0.001    0.000    0.001    0.000 {method '__array_wrap__' of 'numpy.ndarray' objects}
#       450    0.001    0.000    0.007    0.000 fromnumeric.py:2092(cumsum)
#       199    0.001    0.000    0.040    0.000 grid.py:170(copy)
#       906    0.001    0.000    0.104    0.000 rect_maxvol.py:115(rect_maxvol)
#       199    0.001    0.000    0.005    0.000 func.py:63(__init__)
#       800    0.001    0.000    0.001    0.000 getlimits.py:532(max)
#       200    0.001    0.000    0.001    0.000 {built-in method _locale.nl_langinfo}
#       400    0.001    0.000    0.001    0.000 linalg.py:170(_to_native_byte_order)
#      1608    0.001    0.000    0.001    0.000 numeric.py:1304(<listcomp>)
#         1    0.001    0.001  447.775  447.775 solver.py:353(calc)
#       100    0.001    0.000    0.058    0.001 iostream.py:334(flush)
#       450    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#      1306    0.001    0.000    0.001    0.000 linalg.py:222(_isEmpty2d)
#       800    0.001    0.000    0.001    0.000 getlimits.py:518(min)
#      1608    0.001    0.000    0.001    0.000 numeric.py:1302(<listcomp>)
#       102    0.001    0.000    0.001    0.000 threading.py:216(__init__)
#       200    0.001    0.000    0.001    0.000 {built-in method _codecs.utf_8_decode}
#       151    0.001    0.000    0.001    0.000 {built-in method builtins.print}
#       102    0.001    0.000    0.013    0.000 iostream.py:382(write)
#       503    0.001    0.000    0.002    0.000 threading.py:1080(is_alive)
#       300    0.001    0.000    0.044    0.000 _numpy_fft.py:73(fft)
#        99    0.001    0.000    0.071    0.001 solver.py:705(_err_calc)
#       200    0.001    0.000    0.002    0.000 _bootlocale.py:33(getpreferredencoding)
#       104    0.001    0.000    0.001    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       100    0.001    0.000    0.049    0.000 threading.py:264(wait)
#       151    0.001    0.000    0.016    0.000 rect_cross.py:411(get_tt)
#       101    0.001    0.000    0.050    0.000 threading.py:534(wait)
#       100    0.001    0.000    0.005    0.000 _tqdm.py:933(__repr__)
#       300    0.001    0.000    0.001    0.000 rect_cross.py:20(__init__)
#      1608    0.001    0.000    0.001    0.000 numeric.py:1309(<listcomp>)
#       100    0.001    0.000    0.071    0.001 _tqdm.py:223(fp_write)
#       400    0.001    0.000    0.050    0.000 rect_maxvol.py:166(maxvol)
#       800    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      1608    0.001    0.000    0.001    0.000 numeric.py:1310(<listcomp>)
#       400    0.001    0.000    0.001    0.000 linalg.py:194(_assertRank2)
#       200    0.001    0.000    0.001    0.000 codecs.py:319(decode)
#       906    0.001    0.000    0.001    0.000 linalg.py:200(_assertRankAtLeast2)
#       104    0.000    0.000    0.000    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       401    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#      1151    0.000    0.000    0.000    0.000 type_check.py:106(real)
#       450    0.000    0.000    0.002    0.000 abc.py:137(__instancecheck__)
#       100    0.000    0.000    0.004    0.000 rect_cross.py:41(<listcomp>)
#        92    0.000    0.000    0.001    0.000 twodim_base.py:140(eye)
#       199    0.000    0.000    0.001    0.000 _tqdm.py:153(format_interval)
#       452    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       909    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#       504    0.000    0.000    0.001    0.000 threading.py:1038(_wait_for_tstate_lock)
#       104    0.000    0.000    0.001    0.000 _tqdm.py:101(release)
#       104    0.000    0.000    0.001    0.000 _tqdm.py:97(acquire)
#       100    0.000    0.000    0.001    0.000 rect_cross.py:40(<listcomp>)
#       403    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#       100    0.000    0.000    0.072    0.001 _tqdm.py:229(print_status)
#       100    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#       102    0.000    0.000    0.001    0.000 threading.py:499(__init__)
#       100    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#        99    0.000    0.000    0.080    0.001 utils.py:65(update)
#       102    0.000    0.000    0.004    0.000 iostream.py:320(_schedule_flush)
#       300    0.000    0.000    0.000    0.000 rect_cross.py:21(<listcomp>)
#        99    0.000    0.000    0.000    0.000 solver.py:404(calc_prep)
#       300    0.000    0.000    0.000    0.000 _numpy_fft.py:66(_unitary)
#       100    0.000    0.000    0.000    0.000 threading.py:252(_acquire_restore)
#        12    0.000    0.000    0.000    0.000 model_fpe_oup.py:150(r0)
#       202    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       151    0.000    0.000    0.000    0.000 rect_cross.py:412(<listcomp>)
#       102    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#       400    0.000    0.000    0.000    0.000 rect_cross.py:28(<listcomp>)
#       100    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#       498    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#       507    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#       104    0.000    0.000    0.001    0.000 _tqdm.py:108(__exit__)
#       102    0.000    0.000    0.000    0.000 threading.py:240(__enter__)
#       104    0.000    0.000    0.001    0.000 _tqdm.py:105(__enter__)
#       298    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       187    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         1    0.000    0.000    0.001    0.001 _tqdm.py:473(_decr_instances)
#       104    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       503    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       102    0.000    0.000    0.000    0.000 threading.py:243(__exit__)
#         1    0.000    0.000    0.001    0.001 _tqdm.py:1121(close)
#         1    0.000    0.000    0.003    0.003 solver.py:579(calc_last)
#       100    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'randn' of 'mtrand.RandomState' objects}
#        99    0.000    0.000    0.000    0.000 _tqdm.py:194(ema)
#       298    0.000    0.000    0.000    0.000 {built-in method time.time}
#       8/2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#       101    0.000    0.000    0.000    0.000 threading.py:255(_is_owned)
#       102    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000  447.775  447.775 {built-in method builtins.exec}
#       102    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 tools.py:315(rand)
#       100    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#       100    0.000    0.000    0.000    0.000 threading.py:249(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:1000(join)
#       102    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 threading.py:1206(current_thread)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#       104    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        12    0.000    0.000    0.002    0.000 func.py:270(func_v)
#         1    0.000    0.000    0.001    0.001 _tqdm.py:689(__init__)
#         1    0.000    0.000    0.000    0.000 _monitor.py:50(exit)
#         1    0.000    0.000    0.000    0.000 threading.py:335(notify)
#       102    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.050    0.050 solver.py:381(calc_init)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:443(__new__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#         1    0.000    0.000    0.000    0.000 threading.py:968(_stop)
#         4    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         1    0.000    0.000    0.000    0.000 _utils.py:131(__eq__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:466(_get_free_pos)
#         1    0.000    0.000  447.775  447.775 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 threading.py:758(__init__)
#         1    0.000    0.000    0.001    0.001 utils.py:58(init)
#         1    0.000    0.000    0.000    0.000 _monitor.py:32(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:829(start)
#       8/2    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         1    0.000    0.000    0.001    0.001 utils.py:74(close)
#        12    0.000    0.000    0.000    0.000 model_fpe_oup.py:132(d)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         2    0.000    0.000    0.000    0.000 _tqdm.py:1140(fp_write)
#         5    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:513(set)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:358(notify_all)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:213(status_printer)
#         2    0.000    0.000    0.000    0.000 _tqdm.py:942(_comparable)
#         2    0.000    0.000    0.000    0.000 _tqdm.py:946(__hash__)
#         1    0.000    0.000    0.000    0.000 _utils.py:158(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:67(__len__)
#         1    0.000    0.000    0.000    0.000 threading.py:728(_newname)
#         1    0.000    0.000    0.000    0.000 utils.py:53(__init__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:1161(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _monitor.py:97(report)
#         1    0.000    0.000    0.000    0.000 _utils.py:144(_is_utf)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:1096(daemon)
#         1    0.000    0.000    0.000    0.000 threading.py:1112(daemon)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10ae296a8}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 _tqdm.py:469(<genexpr>)

# %%
MD = Model.select('fpe_oup')
MD.init(d=3, s=1., D=0.5, A=np.array([
    [1.0, 0.2, 0.5],
    [0.0, 0.7, 0.3],
    [0.0, 0.0, 1.5],
]))

SL = Solver(
    TG=Grid(d=1, n=  100, l=[+0., +8.], k='u'),
    SG=Grid(d=3, n=  20, l=[-6., +6.], k='c'),
    MD=MD, eps=1.E-4, with_tt=True
).init({
    'n_hst': 0,
    'with_rhs': False,
    'with_r_hst': False,
}).prep()

# %prun SL.calc()

print(len(SL.xxx))
print(np.max(SL.xxx))
print(np.mean(SL.xxx))
print(np.min(SL.xxx))
print(np.sum(SL.xxx))
print(SL.res_conv)
# Out:
# Solve: 100%|██████████████████████████████████| 99/99 [01:19<00:00,  1.67step/s]
#  894
# 0.412238612000003
# 0.08274576786353484
# 0.004171270000000504
# 73.97471647000015
# {'evals': 12260, 't_func': 0.0, 'iters': 1, 'err_rel': 9e-07, 'err_abs': 2.6e-07, 'erank': 18.5}
#          40194159 function calls (40192563 primitive calls) in 79.304 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   2138720   16.767    0.000   43.934    0.000 grid.py:510(is_out)
#   3081009   13.532    0.000   13.532    0.000 {built-in method numpy.core.multiarray.c_einsum}
#       894   12.818    0.014   73.924    0.083 func.py:358(comp)
#   3823026   12.571    0.000   12.571    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#   3813918    5.648    0.000   18.707    0.000 fromnumeric.py:64(_wrapreduction)
#   3809780    3.717    0.000   22.350    0.000 fromnumeric.py:2227(amax)
#   2138720    2.973    0.000    4.192    0.000 grid.py:623(_prep_poi)
#   3081009    1.859    0.000   15.906    0.000 einsumfunc.py:983(einsum)
#   8582959    1.589    0.000    1.591    0.000 {built-in method builtins.isinstance}
#     21000    0.748    0.000    0.748    0.000 {built-in method numpy.core.multiarray.concatenate}
#     13613    0.634    0.000    0.634    0.000 {built-in method numpy.core.multiarray.copyto}
#       894    0.620    0.001    1.317    0.001 polycheb.py:3(polycheb)
#   3813918    0.590    0.000    0.590    0.000 {method 'items' of 'dict' objects}
#   3081009    0.515    0.000    0.515    0.000 {method 'pop' of 'dict' objects}
#      1788    0.360    0.000    0.899    0.001 ord_solver.py:87(comp)
#   2169541    0.289    0.000    0.289    0.000 {built-in method builtins.len}
#       651    0.270    0.000    0.291    0.000 vector.py:415(norm)
#       369    0.254    0.001    0.281    0.001 vector.py:381(round)
#      5700    0.244    0.000    0.244    0.000 {method 'repeat' of 'numpy.ndarray' objects}
#       906    0.193    0.000    0.343    0.000 grid.py:193(comp)
#      7152    0.147    0.000    0.147    0.000 model_fpe_oup.py:140(f0)
#       906    0.147    0.000    0.170    0.000 linalg.py:1418(svd)
#       906    0.114    0.000    0.121    0.000 {tt.cross.rectcross.rect_maxvol.cython_boost.maxvol.c_rect_maxvol}
#     65209    0.103    0.000    0.103    0.000 {built-in method numpy.core.multiarray.array}
#      6236    0.094    0.000    0.112    0.000 numeric.py:1048(outer)
#      1392    0.093    0.000    0.107    0.000 vector.py:107(to_list)
#      3576    0.093    0.000    0.137    0.000 model_fpe_oup.py:145(f1)
#       800    0.092    0.000    0.092    0.000 {built-in method numpy.linalg.lapack_lite.dgeqrf}
#       894    0.088    0.000   75.109    0.084 solver.py:489(step)
#      3164    0.079    0.000    0.079    0.000 {built-in method numpy.core.multiarray.dot}
#      6236    0.074    0.000    0.941    0.000 shape_base.py:970(kron)
#       889    0.074    0.000    0.074    0.000 {method 'acquire' of '_thread.lock' objects}
#      1608    0.072    0.000    0.212    0.000 numeric.py:1132(tensordot)
#     14413    0.071    0.000    0.071    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     28278    0.063    0.000    0.063    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       100    0.060    0.001    0.061    0.001 {method 'readlines' of '_io._IOBase' objects}
#       200    0.060    0.000    0.062    0.000 {built-in method io.open}
#      1093    0.059    0.000    0.187    0.000 grid.py:65(__init__)
#       400    0.059    0.000    0.069    0.000 {tt.cross.rectcross.rect_maxvol.cython_boost.maxvol.c_maxvol}
#       250    0.057    0.000    0.073    0.000 vector.py:354(__add__)
#      3576    0.055    0.000    0.436    0.000 solver.py:457(func)
#       300    0.051    0.000    0.051    0.000 {mkl_fft._pydfti.fft}
#       453    0.047    0.000   38.439    0.085 rect_cross.py:339(update_core_right)
#     14515    0.041    0.000    0.041    0.000 {built-in method numpy.core.multiarray.empty}
#       200    0.039    0.000    0.039    0.000 {method 'close' of '_io.TextIOWrapper' objects}
#       453    0.037    0.000   38.456    0.085 rect_cross.py:295(update_core_left)
#       100    0.035    0.000    0.035    0.000 {built-in method posix.remove}
#      4372    0.033    0.000    0.091    0.000 _methods.py:58(_mean)
#       403    0.032    0.000    0.032    0.000 socket.py:334(send)
#       906    0.032    0.000   75.494    0.083 func.py:253(func)
#       400    0.032    0.000    0.211    0.001 linalg.py:738(qr)
#     11366    0.030    0.000    0.070    0.000 {built-in method builtins.sorted}
#       200    0.029    0.000    0.331    0.002 rect_cross.py:198(left_qr_maxvol)
#       151    0.027    0.000   77.055    0.510 rect_cross.py:390(iterate)
#      9540    0.026    0.000    0.042    0.000 shape_base.py:63(atleast_2d)
#     13613    0.025    0.000    0.696    0.000 numeric.py:156(ones)
#      3312    0.022    0.000    0.022    0.000 {built-in method numpy.core.multiarray.arange}
#       450    0.020    0.000    0.035    0.000 vector.py:423(__rmul__)
#      6315    0.019    0.000    0.019    0.000 {built-in method numpy.core.multiarray.zeros}
#     13180    0.018    0.000    0.299    0.000 fromnumeric.py:49(_wrapfunc)
#      1347    0.018    0.000    0.018    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#      5683    0.018    0.000    0.065    0.000 shape_base.py:946(get_array_prepare)
#      5567    0.018    0.000    0.018    0.000 {method 'astype' of 'numpy.ndarray' objects}
#    1593/1    0.018    0.000   79.304   79.304 utils.py:28(timer__)
#      7152    0.017    0.000    0.524    0.000 ord_solver.py:130(func)
#       200    0.017    0.000    0.266    0.001 rect_cross.py:229(right_qr_maxvol)
#     27804    0.017    0.000    0.034    0.000 numeric.py:504(asanyarray)
#       300    0.017    0.000    0.079    0.000 func.py:597(interpolate_cheb)
#      4372    0.016    0.000    0.017    0.000 _methods.py:48(_count_reduce_items)
#     17049    0.016    0.000    0.025    0.000 shape_base.py:951(<genexpr>)
#       250    0.016    0.000    0.025    0.000 vector.py:126(erank)
#       300    0.015    0.000    0.026    0.000 func.py:675(integrate_cheb_coeffs)
#       449    0.015    0.000    0.089    0.000 vector.py:81(from_list)
#      2167    0.015    0.000    0.052    0.000 vector.py:51(__init__)
#     37221    0.014    0.000    0.014    0.000 {built-in method builtins.getattr}
#      4372    0.014    0.000    0.105    0.000 fromnumeric.py:2817(mean)
#       800    0.014    0.000    0.014    0.000 {built-in method numpy.linalg.lapack_lite.dorgqr}
#       100    0.014    0.000   78.024    0.780 rect_cross.py:417(cross)
#       400    0.014    0.000    0.014    0.000 {method 'outer' of 'numpy.ufunc' objects}
#       906    0.014    0.000    0.791    0.001 rect_cross.py:176(index_merge)
#      1812    0.012    0.000    0.012    0.000 {method 'dot' of 'numpy.ndarray' objects}
#      4770    0.012    0.000    0.140    0.000 shape_base.py:182(vstack)
#        99    0.011    0.000   78.603    0.794 solver.py:443(calc_conv)
#      1520    0.011    0.000    0.020    0.000 type_check.py:185(iscomplex)
#       100    0.011    0.000   78.322    0.783 func.py:229(prep)
#       198    0.011    0.000    0.385    0.002 solver.py:416(calc_diff)
#      4138    0.011    0.000    0.087    0.000 fromnumeric.py:1821(sum)
#      6130    0.011    0.000    0.057    0.000 rect_cross.py:12(reshape)
#      5683    0.010    0.000    0.034    0.000 shape_base.py:958(get_array_wrap)
#       100    0.010    0.000    0.054    0.001 func.py:425(comp_int)
#     17049    0.010    0.000    0.014    0.000 shape_base.py:963(<genexpr>)
#      1200    0.010    0.000    0.010    0.000 {built-in method numpy.core.multiarray._fastCopyAndTranspose}
#      6236    0.010    0.000    0.951    0.000 rect_cross.py:15(mkron)
#       100    0.009    0.000    0.172    0.002 func.py:316(calc)
#     29292    0.009    0.000    0.009    0.000 {built-in method builtins.hasattr}
#      6130    0.009    0.000    0.046    0.000 fromnumeric.py:185(reshape)
#      4828    0.009    0.000    0.018    0.000 shape_base.py:11(atleast_1d)
#     16994    0.009    0.000    0.016    0.000 numeric.py:433(asarray)
#       906    0.009    0.000    0.013    0.000 twodim_base.py:197(diag)
#      4770    0.009    0.000    0.050    0.000 shape_base.py:234(<listcomp>)
#       895    0.008    0.000    0.013    0.000 func.py:141(init)
#        99    0.008    0.000    0.115    0.001 solver.py:699(exam)
#      1788    0.008    0.000    0.010    0.000 ord_solver.py:17(__init__)
#       450    0.007    0.000    0.019    0.000 vector.py:544(get_ps)
#      5700    0.007    0.000    0.259    0.000 fromnumeric.py:404(repeat)
#     20927    0.007    0.000    0.007    0.000 {method 'append' of 'list' objects}
#     12472    0.007    0.000    0.007    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      1306    0.007    0.000    0.012    0.000 linalg.py:141(_commonType)
#      8574    0.006    0.000    0.006    0.000 {built-in method time.perf_counter}
#      3216    0.006    0.000    0.006    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       400    0.005    0.000    0.031    0.000 twodim_base.py:327(tri)
#      1961    0.005    0.000    0.023    0.000 shape_base.py:283(<listcomp>)
#       400    0.005    0.000    0.005    0.000 {built-in method numpy.core.multiarray.unravel_index}
#     13489    0.005    0.000    0.005    0.000 {built-in method builtins.issubclass}
#      1200    0.005    0.000    0.015    0.000 linalg.py:182(_fastCopyAndTranspose)
#      1961    0.005    0.000    0.046    0.000 shape_base.py:236(hstack)
#      4475    0.005    0.000    0.005    0.000 func.py:217(set_opt)
#       648    0.004    0.000    0.030    0.000 vector.py:559(copy)
#       450    0.004    0.000    0.004    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#       199    0.004    0.000    0.070    0.000 func.py:94(copy)
#       453    0.004    0.000    0.067    0.000 rect_cross.py:262(apply_Ru)
#       100    0.004    0.000    0.601    0.006 rect_cross.py:283(setup_indices)
#       453    0.003    0.000    0.037    0.000 rect_cross.py:272(apply_Rv)
#       100    0.003    0.000    0.006    0.000 grid.py:568(is_sym)
#      1306    0.003    0.000    0.006    0.000 linalg.py:108(_makearray)
#       199    0.003    0.000    0.008    0.000 func.py:63(__init__)
#       400    0.003    0.000    0.039    0.000 twodim_base.py:414(triu)
#       100    0.003    0.000    0.026    0.000 rect_cross.py:145(init_alg)
#      3576    0.003    0.000    0.003    0.000 ord_solver.py:50(init)
#      1608    0.003    0.000    0.003    0.000 {built-in method builtins.iter}
#       100    0.003    0.000    0.006    0.000 _tqdm.py:236(format_meter)
#       400    0.003    0.000    0.003    0.000 {built-in method numpy.core.multiarray.where}
#      8295    0.002    0.000    0.002    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#      2212    0.002    0.000    0.004    0.000 linalg.py:126(_realType)
#       906    0.002    0.000    0.002    0.000 linalg.py:103(get_linalg_error_extobj)
#      1520    0.002    0.000    0.018    0.000 {method 'any' of 'numpy.ndarray' objects}
#       800    0.002    0.000    0.004    0.000 twodim_base.py:25(_min_int)
#        99    0.002    0.000    0.130    0.001 _tqdm.py:1040(update)
#        99    0.002    0.000    0.278    0.003 solver.py:529(calc_post)
#      2720    0.002    0.000    0.022    0.000 function_base.py:689(copy)
#       900    0.002    0.000    0.002    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#       403    0.002    0.000    0.037    0.000 iostream.py:195(schedule)
#      3012    0.002    0.000    0.003    0.000 linalg.py:113(isComplexType)
#       597    0.002    0.000    0.002    0.000 {method 'format' of 'str' objects}
#       400    0.002    0.000    0.002    0.000 linalg.py:170(_to_native_byte_order)
#      1306    0.002    0.000    0.003    0.000 linalg.py:226(_assertNoEmpty2d)
#       100    0.002    0.000    0.004    0.000 rect_cross.py:38(__init__)
#       250    0.002    0.000    0.093    0.000 vector.py:455(__sub__)
#      3605    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      1608    0.001    0.000    0.001    0.000 numeric.py:1296(<listcomp>)
#       199    0.001    0.000    0.042    0.000 grid.py:170(copy)
#       450    0.001    0.000    0.006    0.000 fromnumeric.py:2092(cumsum)
#      5683    0.001    0.000    0.001    0.000 {method '__array_wrap__' of 'numpy.ndarray' objects}
#       906    0.001    0.000    0.123    0.000 rect_maxvol.py:115(rect_maxvol)
#         1    0.001    0.001   79.304   79.304 solver.py:353(calc)
#       900    0.001    0.000    0.006    0.000 fromnumeric.py:506(swapaxes)
#      1520    0.001    0.000    0.016    0.000 _methods.py:42(_any)
#       450    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#       503    0.001    0.000    0.002    0.000 threading.py:1080(is_alive)
#       800    0.001    0.000    0.001    0.000 getlimits.py:532(max)
#       102    0.001    0.000    0.001    0.000 threading.py:216(__init__)
#      1608    0.001    0.000    0.001    0.000 numeric.py:1304(<listcomp>)
#       200    0.001    0.000    0.001    0.000 {built-in method _locale.nl_langinfo}
#      1306    0.001    0.000    0.001    0.000 linalg.py:222(_isEmpty2d)
#       800    0.001    0.000    0.001    0.000 getlimits.py:518(min)
#        99    0.001    0.000    0.094    0.001 solver.py:700(_err_calc)
#       100    0.001    0.000    0.098    0.001 iostream.py:334(flush)
#       200    0.001    0.000    0.002    0.000 _bootlocale.py:33(getpreferredencoding)
#       104    0.001    0.000    0.001    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       104    0.001    0.000    0.002    0.000 _tqdm.py:97(acquire)
#       151    0.001    0.000    0.001    0.000 {built-in method builtins.print}
#      1608    0.001    0.000    0.001    0.000 numeric.py:1302(<listcomp>)
#       300    0.001    0.000    0.001    0.000 rect_cross.py:20(__init__)
#       151    0.001    0.000    0.017    0.000 rect_cross.py:411(get_tt)
#      1608    0.001    0.000    0.001    0.000 numeric.py:1301(<listcomp>)
#        96    0.001    0.000    0.075    0.001 threading.py:264(wait)
#       102    0.001    0.000    0.020    0.000 iostream.py:382(write)
#       100    0.001    0.000    0.118    0.001 _tqdm.py:223(fp_write)
#      1608    0.001    0.000    0.001    0.000 numeric.py:1309(<listcomp>)
#       300    0.001    0.000    0.051    0.000 _numpy_fft.py:73(fft)
#       100    0.001    0.000    0.007    0.000 _tqdm.py:933(__repr__)
#       200    0.001    0.000    0.001    0.000 codecs.py:319(decode)
#       101    0.001    0.000    0.076    0.001 threading.py:534(wait)
#       104    0.001    0.000    0.001    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       800    0.001    0.000    0.001    0.000 {method 'split' of 'str' objects}
#      1608    0.001    0.000    0.001    0.000 numeric.py:1310(<listcomp>)
#       400    0.001    0.000    0.070    0.000 rect_maxvol.py:166(maxvol)
#       400    0.001    0.000    0.001    0.000 rect_cross.py:27(__init__)
#       906    0.001    0.000    0.001    0.000 linalg.py:200(_assertRankAtLeast2)
#       199    0.001    0.000    0.002    0.000 _tqdm.py:153(format_interval)
#      1151    0.001    0.000    0.001    0.000 type_check.py:106(real)
#       909    0.001    0.000    0.001    0.000 {built-in method builtins.abs}
#       452    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#       400    0.001    0.000    0.001    0.000 linalg.py:194(_assertRank2)
#       401    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#       504    0.001    0.000    0.001    0.000 threading.py:1038(_wait_for_tstate_lock)
#       497    0.001    0.000    0.001    0.000 {method 'copy' of 'dict' objects}
#       450    0.000    0.000    0.002    0.000 abc.py:137(__instancecheck__)
#       102    0.000    0.000    0.007    0.000 iostream.py:320(_schedule_flush)
#       100    0.000    0.000    0.118    0.001 _tqdm.py:229(print_status)
#       104    0.000    0.000    0.001    0.000 _tqdm.py:101(release)
#       100    0.000    0.000    0.002    0.000 rect_cross.py:40(<listcomp>)
#       100    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#        91    0.000    0.000    0.001    0.000 twodim_base.py:140(eye)
#       403    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#       200    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#        99    0.000    0.000    0.000    0.000 solver.py:404(calc_prep)
#        99    0.000    0.000    0.131    0.001 utils.py:65(update)
#       100    0.000    0.000    0.000    0.000 codecs.py:309(__init__)
#       102    0.000    0.000    0.002    0.000 threading.py:499(__init__)
#       100    0.000    0.000    0.001    0.000 rect_cross.py:41(<listcomp>)
#        12    0.000    0.000    0.001    0.000 model_fpe_oup.py:150(r0)
#       498    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#       300    0.000    0.000    0.000    0.000 _numpy_fft.py:66(_unitary)
#       102    0.000    0.000    0.000    0.000 iostream.py:307(_is_master_process)
#       300    0.000    0.000    0.000    0.000 rect_cross.py:21(<listcomp>)
#       151    0.000    0.000    0.000    0.000 rect_cross.py:412(<listcomp>)
#       198    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       100    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#       400    0.000    0.000    0.000    0.000 rect_cross.py:28(<listcomp>)
#       104    0.000    0.000    0.001    0.000 _tqdm.py:108(__exit__)
#       507    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#       104    0.000    0.000    0.002    0.000 _tqdm.py:105(__enter__)
#       298    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#       102    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        96    0.000    0.000    0.000    0.000 threading.py:252(_acquire_restore)
#        99    0.000    0.000    0.000    0.000 _tqdm.py:194(ema)
#       187    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#       499    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#       102    0.000    0.000    0.000    0.000 threading.py:240(__enter__)
#       104    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       298    0.000    0.000    0.000    0.000 {built-in method time.time}
#       100    0.000    0.000    0.000    0.000 codecs.py:260(__init__)
#       102    0.000    0.000    0.000    0.000 threading.py:243(__exit__)
#       102    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.003    0.003 solver.py:574(calc_last)
#        96    0.000    0.000    0.000    0.000 threading.py:249(_release_save)
#       104    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#        97    0.000    0.000    0.000    0.000 threading.py:255(_is_owned)
#       100    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#       102    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 tools.py:315(rand)
#         1    0.000    0.000    0.000    0.000 {method 'randn' of 'mtrand.RandomState' objects}
#        98    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000   79.304   79.304 {built-in method builtins.exec}
#         1    0.000    0.000    0.001    0.001 _tqdm.py:689(__init__)
#         1    0.000    0.000    0.024    0.024 solver.py:381(calc_init)
#       3/1    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 _tqdm.py:443(__new__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:473(_decr_instances)
#         1    0.000    0.000    0.001    0.001 utils.py:58(init)
#         1    0.000    0.000    0.001    0.001 _tqdm.py:1121(close)
#         4    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         2    0.000    0.000    0.000    0.000 _tqdm.py:1140(fp_write)
#         1    0.000    0.000    0.000    0.000 threading.py:758(__init__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:466(_get_free_pos)
#         1    0.000    0.000    0.000    0.000 _monitor.py:32(__init__)
#        12    0.000    0.000    0.000    0.000 model_fpe_oup.py:132(d)
#         4    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:335(notify)
#         1    0.000    0.000    0.000    0.000 _monitor.py:50(exit)
#         1    0.000    0.000    0.000    0.000 threading.py:829(start)
#         1    0.000    0.000    0.000    0.000 threading.py:968(_stop)
#         1    0.000    0.000    0.000    0.000 threading.py:1000(join)
#         2    0.000    0.000    0.000    0.000 threading.py:1206(current_thread)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#       3/1    0.000    0.000    0.000    0.000 abc.py:141(__subclasscheck__)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:36(__init__)
#         5    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#         1    0.000    0.000    0.000    0.000 threading.py:513(set)
#         1    0.000    0.000   79.304   79.304 <string>:1(<module>)
#         1    0.000    0.000    0.001    0.001 utils.py:74(close)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:213(status_printer)
#         2    0.000    0.000    0.000    0.000 _tqdm.py:946(__hash__)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:358(notify_all)
#         1    0.000    0.000    0.000    0.000 threading.py:728(_newname)
#         1    0.000    0.000    0.000    0.000 threading.py:1112(daemon)
#         2    0.000    0.000    0.000    0.000 _tqdm.py:942(_comparable)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:1161(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _monitor.py:97(report)
#         1    0.000    0.000    0.000    0.000 _utils.py:144(_is_utf)
#         1    0.000    0.000    0.000    0.000 _utils.py:158(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:67(__len__)
#         1    0.000    0.000    0.000    0.000 threading.py:1096(daemon)
#         1    0.000    0.000    0.000    0.000 utils.py:53(__init__)
#         1    0.000    0.000    0.000    0.000 _tqdm.py:469(<genexpr>)
#         1    0.000    0.000    0.000    0.000 _utils.py:131(__eq__)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1033ef6a8}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
def func(x):
    return 2. * np.sin(np.pi * x[0, ]) + np.exp(-x[1, ]) + x[2, ] / 2.

GR = Grid(d=3, n=[20, 22, 24], l=[
    [-3., 4.],
    [-2., 3.],
    [-1., 1.],
])
FN = Func(GR, eps=1.E-6, with_tt=True)
FN.init(func, opts={
    'with_Y_hst': True,
})
FN.prep()
FN.calc()
FN.info(n_test=100)

e = FN.test(n=1000, is_u=True)
print('-->Test (uni.gr.)|\nError (max)      : %-8.0e'%np.max(np.abs(e)))
# Out:
# ------------------ Function
# Format           : 3D, TT, eps= 1.00e-06
# --> Time (sec.)  |
# Prep             : 1.45e-01
# Calc             : 7.02e-04
# Comp (average)   : 4.10e-05
# Func (average)   : 5.11e-05
# --> Test         |
# Random points    :      Yes
# Number of points :      100
# Error (max)      : 1.77e-02
# Error (mean)     : 4.99e-04
# Error (min)      : 2.51e-06
# --> Cross params |
# Initial guess    :       No
# nswp             :      200
# kickrank         :        1
# rf               : 2.00e+00
# --> Cross result |
# Func. evaluations:     1685
# Cross iterations :        3
# Av. tt-rank      : 7.50e+00
# Cross err (rel)  : 4.40e-16
# Cross err (abs)  : 1.50e-13
# -->Test (uni.gr.)|
# Error (max)      : 4e-02

# %%
def func(x):
    return 2. * np.sin(np.pi * x[0, ]) + np.exp(-x[1, ]) + x[2, ] / 2.

GR = Grid(d=3, n=[20, 22, 24], l=[
    [-3., 4.],
    [-2., 3.],
    [-1., 1.],
])
FN = Func(GR, eps=1.E-6, with_tt=True)
FN.init(func)
FN.prep()
FN.calc()
FN.info(n_test=100)

e = FN.test(n=1000, is_u=True)
print('-->Test (uni.gr.)|\nError (max)      : %-8.0e'%np.max(np.abs(e)))
# Out:
# ------------------ Function
# Format           : 3D, TT, eps= 1.00e-06
# --> Time (sec.)  |
# Prep             : 3.23e-02
# Calc             : 8.72e-04
# Comp (average)   : 4.78e-05
# Func (average)   : 8.94e-07
# --> Test         |
# Random points    :      Yes
# Number of points :      100
# Error (max)      : 2.54e-02
# Error (mean)     : 6.34e-04
# Error (min)      : 6.35e-07
# --> Cross params |
# Initial guess    :       No
# nswp             :      200
# kickrank         :        1
# rf               : 2.00e+00
# --> Cross result |
# Func. evaluations:     3540
# Cross iterations :        3
# Av. tt-rank      : 7.50e+00
# Cross err (rel)  : 4.40e-16
# Cross err (abs)  : 1.50e-13
# -->Test (uni.gr.)|
# Error (max)      : 4e-02

# %% [markdown]
# 2138720   16.459    0.000   42.941    0.000 grid.py:510(is_out)
# 3081009   13.277    0.000   13.277    0.000 {built-in method numpy.core.multiarray.c_einsum}
# 894   12.669    0.014   72.437    0.081 func.py:358(comp)
# 3823026   12.173    0.000   12.173    0.000 {method 'reduce' of 'numpy.ufunc' objects}
# 3813918    5.449    0.000   18.110    0.000 fromnumeric.py:64(_wrapreduction)
#
# В общем, предсказуемо получается, что основное время потребляет вычисление результата интерполяции в заданных точках (по запросу креста) - это func.py:358(comp). Первые две строчки выдачи prun - это тоже самое (из
#
#
# Получается, что много времени уходит на функцию is_out. Она проверяет при вычислении значения интерполянта в точке - лежит ли точка вне пределов интерполяции и реализована тривиально:
#
# np.max(l[:, 0] - x) > eps or np.max(x - l[:, 1]) > eps
#
# где l - это пределы области [dimensions, 2]
#
# Без этой проверки я не смогу занулять точки (прообразы), вывалившиеся за пределы области интерполяции
#
# Еще много времени уходит на func.comp - это, опять же, вычисление интерполянта в заданных точках. Работает медленно, поскольку для каждой точки (запрашиваемой крестом) я вынужден вычислять отдельно (не векторизовано).
